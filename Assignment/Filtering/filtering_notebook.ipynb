# %% [markdown]
# ## Import packages

# %%
import numpy as np
from PIL import Image
from scipy.signal import convolve2d as conv2
import matplotlib.pyplot as plt

import gauss_module
import importlib
importlib.reload(gauss_module)
from time import time

# %%
def rgb2gray(rgb):

    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b

    return gray

# %% [markdown]
# ### Function gauss (Question 1.a)

# %%
sigma =4.0
[Gx, x] = gauss_module.gauss(sigma)

plt.figure(1)
plt.plot(x, Gx, '.-')
#plt.xlim(-20,20)
plt.show()

# %% [markdown]
# ### Function gaussianfilter (Question 1.b)

# %%
img = rgb2gray(np.array(Image.open('graf.png')))
t1=time()
smooth_img = gaussianfilter(img, 4)
t2=(time()-t1)
print(t2)
plt.figure(2, figsize=(20, 20))
ax1 = plt.subplot(1,2,1)
ax2 = plt.subplot(1,2,2)
plt.sca(ax1)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.sca(ax2)
plt.imshow(smooth_img, cmap='gray', vmin=0, vmax=255)
plt.show()
# Out:
# 0.3590400218963623

# %%
from scipy.ndimage import gaussian_filter #check with the scipy function

img = rgb2gray(np.array(Image.open('graf.png')))
t1=time()
smooth_img = gaussian_filter(img, 4)
t2=(time()-t1)
print(t2)

plt.figure(2, figsize=(20, 20))
ax1 = plt.subplot(1,2,1)
ax2 = plt.subplot(1,2,2)
plt.sca(ax1)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.sca(ax2)
plt.imshow(smooth_img, cmap='gray', vmin=0, vmax=255)
plt.show()
# Out:
# 0.01595759391784668

# %%
img = rgb2gray(np.array(Image.open('totti.jpg')))
t1=time()
smooth_img = gaussianfilter(img, 4)
t2=(time()-t1)
print(t2)
plt.figure(2, figsize=(20, 20))
ax1 = plt.subplot(1,2,1)
ax2 = plt.subplot(1,2,2)
plt.sca(ax1)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.sca(ax2)
plt.imshow(smooth_img, cmap='gray', vmin=0, vmax=255)
plt.show()
# Out:
# 0.21941328048706055
