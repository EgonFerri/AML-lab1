# %% [markdown]
# ## Import packages

# %%
import numpy as np
from PIL import Image
from scipy.signal import convolve2d as conv2
import matplotlib.pyplot as plt

import gauss_module
import importlib
importlib.reload(gauss_module)
# Out:
# <module 'gauss_module' from 'C:\\Users\\Egon\\Desktop\\Universita\\ultimosemestre\\AML\\labs\\Ex1_filtering_recognintion\\AML-lab1\\Assignment\\Filtering\\gauss_module.py'>

# %%
def rgb2gray(rgb):

    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b

    return gray

# %% [markdown]
# ### Function gauss (Question 1.a)

# %%
sigma =4.0
[Gx, x] = gauss_module.gauss(sigma)

plt.figure(1)
plt.plot(x, Gx, '.-')
#plt.xlim(-20,20)
plt.show()

# %% [markdown]
# ### Function gaussianfilter (Question 1.b)

# %%
img = rgb2gray(np.array(Image.open('graf.png')))
#smooth_img = gauss_module.gaussianfilter(img, sigma)

plt.figure(2)
ax1 = plt.subplot(1,2,1)
ax2 = plt.subplot(1,2,2)
plt.sca(ax1)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.sca(ax2)
#plt.imshow(smooth_img, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
img
# Out:
# array([[212.6521, 209.9944, 200.2234, ...,  26.079 ,  29.4809,  20.998 ],
#        [209.8373, 214.0649, 213.407 , ...,  32.8271,  26.4472,  23.1918],
#        [213.9078, 213.5488, 210.8911, ...,  30.436 ,  29.8598,  27.3655],
#        ...,
#        [ 70.0112,  66.2566,  69.7894, ...,  38.7341,  37.4353,  41.25  ],
#        [ 68.6432,  75.3544,  78.4681, ...,  41.6799,  40.5059,  41.0929],
#        [ 77.2895,  76.7564,  76.6362, ...,  43.2838,  42.6537,  37.9639]])
